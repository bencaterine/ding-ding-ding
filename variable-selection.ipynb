# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
airlines = pd.read_csv('data/airlines.csv')
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
airports = pd.read_csv('data/airports.csv')
airports.columns = airports.columns.str.lower()
airports
# Out:
#     iata_code                              airport  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                city state country  latitude  longitude
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
flights = pd.read_csv('data/flights.csv')
flights.columns = flights.columns.str.lower()
flights = flights.merge(right=airports, how='left', left_on='origin_airport', right_on='iata_code')
flights
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          year  month  day  day_of_week airline  flight_number tail_number  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         origin_airport destination_airport  scheduled_departure  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          airline_delay  late_aircraft_delay  weather_delay  iata_code  \
# 0                  NaN                  NaN            NaN        ANC
# 1                  NaN                  NaN            NaN        LAX
# 2                  NaN                  NaN            NaN        SFO
# 3                  NaN                  NaN            NaN        LAX
# 4                  NaN                  NaN            NaN        SEA
# ...                ...                  ...            ...        ...
# 5819074            NaN                  NaN            NaN        LAX
# 5819075            NaN                  NaN            NaN        JFK
# 5819076            NaN                  NaN            NaN        JFK
# 5819077            NaN                  NaN            NaN        MCO
# 5819078            NaN                  NaN            NaN        JFK
#
#                                                    airport           city  \
# 0              Ted Stevens Anchorage International Airport      Anchorage
# 1                        Los Angeles International Airport    Los Angeles
# 2                      San Francisco International Airport  San Francisco
# 3                        Los Angeles International Airport    Los Angeles
# 4                     Seattle-Tacoma International Airport        Seattle
# ...                                                    ...            ...
# 5819074                  Los Angeles International Airport    Los Angeles
# 5819075  John F. Kennedy International Airport (New Yor...       New York
# 5819076  John F. Kennedy International Airport (New Yor...       New York
# 5819077                      Orlando International Airport        Orlando
# 5819078  John F. Kennedy International Airport (New Yor...       New York
#
#          state  country  latitude  longitude
# 0           AK      USA  61.17432 -149.99619
# 1           CA      USA  33.94254 -118.40807
# 2           CA      USA  37.61900 -122.37484
# 3           CA      USA  33.94254 -118.40807
# 4           WA      USA  47.44898 -122.30931
# ...        ...      ...       ...        ...
# 5819074     CA      USA  33.94254 -118.40807
# 5819075     NY      USA  40.63975  -73.77893
# 5819076     NY      USA  40.63975  -73.77893
# 5819077     FL      USA  28.42889  -81.31603
# 5819078     NY      USA  40.63975  -73.77893
#
# [5819079 rows x 38 columns]

# %%
flights.dtypes
# Out:
# year                     int64
# month                    int64
# day                      int64
# day_of_week              int64
# airline                 object
# flight_number            int64
# tail_number             object
# origin_airport          object
# destination_airport     object
# scheduled_departure      int64
# departure_time         float64
# departure_delay        float64
# taxi_out               float64
# wheels_off             float64
# scheduled_time         float64
# elapsed_time           float64
# air_time               float64
# distance                 int64
# wheels_on              float64
# taxi_in                float64
# scheduled_arrival        int64
# arrival_time           float64
# arrival_delay          float64
# diverted                 int64
# cancelled                int64
# cancellation_reason     object
# air_system_delay       float64
# security_delay         float64
# airline_delay          float64
# late_aircraft_delay    float64
# weather_delay          float64
# iata_code               object
# airport                 object
# city                    object
# state                   object
# country                 object
# latitude               float64
# longitude              float64
# dtype: object

# %%
X = flights[flights.columns.difference([
    'departure_delay', # response variable
    'year', # all are 2015
    'flight_number', # irrelevant
    'tail_number', # irrelevant
    'departure_time', # collinearity: scheduled_departure + departure_delay
    'wheels_off', # co: departure_time + taxi_out
    'elapsed_time', # co: scheduled_time + departure_delay
    'air_time', # co: elapsed_time - taxi_out - taxi_in
    'wheels_on', # co: arrival_time - taxi_in
    # leave in arrival_time because of time changes
    'arrival_delay', # co: departure_delay
    'diverted', # occurs after delay, can't be used to predict delay time
    'cancelled', # occurs after delay,
    'cancellation_reason',
    'air_system_delay',
    'security_delay',
    'airline_delay',
    'late_aircraft_delay',
    'weather_delay',
    'iata_code', # same as origin_airport
    'airport', # airport already described in origin_airport
    'country' # all are USA
])]

# %%
y = flights.departure_delay

# %%
X.head()
# Out:
#   airline  arrival_time           city  day  day_of_week destination_airport  \
# 0      AS         408.0      Anchorage    1            4                 SEA
# 1      AA         741.0    Los Angeles    1            4                 PBI
# 2      US         811.0  San Francisco    1            4                 CLT
# 3      AA         756.0    Los Angeles    1            4                 MIA
# 4      AS         259.0        Seattle    1            4                 ANC
#
#    distance  latitude  longitude  month origin_airport  scheduled_arrival  \
# 0      1448  61.17432 -149.99619      1            ANC                430
# 1      2330  33.94254 -118.40807      1            LAX                750
# 2      2296  37.61900 -122.37484      1            SFO                806
# 3      2342  33.94254 -118.40807      1            LAX                805
# 4      1448  47.44898 -122.30931      1            SEA                320
#
#    scheduled_departure  scheduled_time state  taxi_in  taxi_out
# 0                    5           205.0    AK      4.0      21.0
# 1                   10           280.0    CA      4.0      12.0
# 2                   20           286.0    CA     11.0      16.0
# 3                   20           285.0    CA      8.0      15.0
# 4                   25           235.0    WA      5.0      11.0

# %%
y.head()
# Out:
# 0   -11.0
# 1    -8.0
# 2    -2.0
# 3    -5.0
# 4    -1.0
# Name: departure_delay, dtype: float64

# %%
flights.corrwith(flights.departure_delay).sort_values(ascending=False)
# Out:
# departure_delay        1.000000
# arrival_delay          0.944672
# airline_delay          0.621296
# late_aircraft_delay    0.554802
# weather_delay          0.243532
# departure_time         0.171723
# wheels_off             0.162582
# scheduled_departure    0.110149
# scheduled_arrival      0.097566
# air_system_delay       0.095917
# wheels_on              0.058674
# taxi_out               0.058515
# arrival_time           0.049236
# cancelled              0.033099
# longitude              0.031857
# elapsed_time           0.030805
# scheduled_time         0.027799
# distance               0.024106
# air_time               0.023495
# diverted               0.022963
# taxi_in                0.012784
# security_delay         0.011877
# latitude              -0.003755
# flight_number         -0.008665
# day_of_week           -0.011510
# year                        NaN
# dtype: float64

# %%
model = smf.ols(formula='departure_delay ~ departure_time + taxi_out + longitude + scheduled_time + month + day', data=flights).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        departure_delay   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     4968.
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:28:38   Log-Likelihood:            -2.6329e+07
# No. Observations:             5241724   AIC:                         5.266e+07
# Df Residuals:                 5241679   BIC:                         5.266e+07
# Df Model:                          44
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -6.8920      0.149    -46.249      0.000      -7.184      -6.600
# month[T.10]     2.533e-12   5.18e-14     48.876      0.000    2.43e-12    2.64e-12
# month[T.11]       -2.8187      0.077    -36.755      0.000      -2.969      -2.668
# month[T.12]        1.9017      0.076     24.923      0.000       1.752       2.051
# month[T.2]         1.8620      0.079     23.471      0.000       1.707       2.018
# month[T.3]        -0.1708      0.075     -2.264      0.024      -0.319      -0.023
# month[T.4]        -2.0195      0.076    -26.571      0.000      -2.168      -1.871
# month[T.5]        -0.2455      0.076     -3.250      0.001      -0.394      -0.097
# month[T.6]         4.0600      0.075     53.805      0.000       3.912       4.208
# month[T.7]         1.5623      0.075     20.926      0.000       1.416       1.709
# month[T.8]         0.1844      0.075      2.457      0.014       0.037       0.331
# month[T.9]        -4.7760      0.077    -62.256      0.000      -4.926      -4.626
# day[T.10]         -0.5296      0.126     -4.207      0.000      -0.776      -0.283
# day[T.11]         -1.9305      0.126    -15.324      0.000      -2.177      -1.684
# day[T.12]         -2.9168      0.126    -23.142      0.000      -3.164      -2.670
# day[T.13]         -1.8059      0.125    -14.425      0.000      -2.051      -1.561
# day[T.14]         -2.0563      0.126    -16.261      0.000      -2.304      -1.808
# day[T.15]         -0.2797      0.126     -2.217      0.027      -0.527      -0.032
# day[T.16]         -1.7189      0.125    -13.706      0.000      -1.965      -1.473
# day[T.17]          1.0848      0.126      8.642      0.000       0.839       1.331
# day[T.18]          2.5918      0.126     20.572      0.000       2.345       2.839
# day[T.19]         -1.0900      0.126     -8.678      0.000      -1.336      -0.844
# day[T.2]          -0.0859      0.126     -0.683      0.494      -0.332       0.160
# day[T.20]          0.4944      0.125      3.944      0.000       0.249       0.740
# day[T.21]         -0.4542      0.127     -3.589      0.000      -0.702      -0.206
# day[T.22]         -1.9392      0.126    -15.410      0.000      -2.186      -1.693
# day[T.23]          0.1960      0.126      1.558      0.119      -0.051       0.443
# day[T.24]         -1.3760      0.127    -10.872      0.000      -1.624      -1.128
# day[T.25]         -3.1568      0.127    -24.916      0.000      -3.405      -2.909
# day[T.26]         -0.4424      0.127     -3.481      0.001      -0.692      -0.193
# day[T.27]         -0.0254      0.126     -0.201      0.841      -0.273       0.222
# day[T.28]         -2.1157      0.126    -16.743      0.000      -2.363      -1.868
# day[T.29]         -2.4671      0.128    -19.244      0.000      -2.718      -2.216
# day[T.3]          -0.8531      0.126     -6.787      0.000      -1.099      -0.607
# day[T.30]          0.0952      0.128      0.742      0.458      -0.156       0.347
# day[T.31]         -2.1857      0.152    -14.378      0.000      -2.484      -1.888
# day[T.4]          -1.1844      0.126     -9.393      0.000      -1.432      -0.937
# day[T.5]          -1.2729      0.127    -10.040      0.000      -1.521      -1.024
# day[T.6]          -1.9073      0.126    -15.141      0.000      -2.154      -1.660
# day[T.7]          -3.2640      0.127    -25.787      0.000      -3.512      -3.016
# day[T.8]          -0.3345      0.126     -2.660      0.008      -0.581      -0.088
# day[T.9]          -0.4885      0.126     -3.881      0.000      -0.735      -0.242
# departure_time     0.0131   3.23e-05    406.784      0.000       0.013       0.013
# taxi_out           0.2037      0.002    112.175      0.000       0.200       0.207
# longitude          0.0516      0.001     57.882      0.000       0.050       0.053
# scheduled_time     0.0124      0.000     57.710      0.000       0.012       0.013
# ==============================================================================
# Omnibus:                  7122559.352   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3535538747.685
# Skew:                           7.599   Prob(JB):                         0.00
# Kurtosis:                     129.321   Cond. No.                     2.26e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.11e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
flights.loc[0]
# Out:
# year                                                          2015
# month                                                            1
# day                                                              1
# day_of_week                                                      4
# airline                                                         AS
# flight_number                                                   98
# tail_number                                                 N407AS
# origin_airport                                                 ANC
# destination_airport                                            SEA
# scheduled_departure                                              5
# departure_time                                              2354.0
# departure_delay                                              -11.0
# taxi_out                                                      21.0
# wheels_off                                                    15.0
# scheduled_time                                               205.0
# elapsed_time                                                 194.0
# air_time                                                     169.0
# distance                                                      1448
# wheels_on                                                    404.0
# taxi_in                                                        4.0
# scheduled_arrival                                              430
# arrival_time                                                 408.0
# arrival_delay                                                -22.0
# diverted                                                         0
# cancelled                                                        0
# cancellation_reason                                            NaN
# air_system_delay                                               NaN
# security_delay                                                 NaN
# airline_delay                                                  NaN
# late_aircraft_delay                                            NaN
# weather_delay                                                  NaN
# iata_code                                                      ANC
# airport                Ted Stevens Anchorage International Airport
# city                                                     Anchorage
# state                                                           AK
# country                                                        USA
# latitude                                                  61.17432
# longitude                                               -149.99619
# Name: 0, dtype: object
